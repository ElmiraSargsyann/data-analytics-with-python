# %% [markdown]
# ## Unziping File

# %%
import zipfile
with zipfile.ZipFile("../data/raw/Archive.zip", "r") as zip_ref:
    zip_ref.extractall("../data/raw")

# %% [markdown]
# ## Installing Packages

# %%
import pandas as pd

# %%
## Reading data
df_orders = pd.read_csv('../data/raw/orders.csv')

print(df_orders.columns)
print(df_orders.shape)
df_orders.head()
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='str')
# (3421083, 7)
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_orders.rename(columns={'order_number':'order_n'}, inplace=True)

# %%
df_orders.shape
# Out:
# (3421083, 7)

# %%
## list of columns
df_orders.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_n', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='str')

# %%
df_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                str
#  3   order_n                 int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), str(1)
# memory usage: 182.7 MB

# %%
df_orders.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                      str
# order_n                     int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
## summary statisctics
df_orders.describe()
# Out:
#            order_id       user_id       order_n     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# max         2.300000e+01            3.000000e+01

# %%
df_orders.drop(columns = ['eval_set'], inplace = True)

# %%
df_orders.columns
# Out:
# Index(['order_id', 'user_id', 'order_n', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order'],
#       dtype='str')

# %%
df_orders_new = df_orders.assign(
    is_weekend = df_orders["order_dow"].isin([0, 6]),
    is_morning = df_orders["order_hour_of_day"] < 12,
    is_premium = df_orders["days_since_prior_order"] <= 7
)

# %%
del df_orders

# %%
df_orders_new.head()
# Out:
#    order_id  user_id  order_n  order_dow  order_hour_of_day  \
# 0   2539329        1        1          2                  8
# 1   2398795        1        2          3                  7
# 2    473747        1        3          3                 12
# 3   2254736        1        4          4                  7
# 4    431534        1        5          4                 15
#
#    days_since_prior_order  is_weekend  is_morning  is_premium
# 0                     NaN       False        True       False
# 1                    15.0       False        True       False
# 2                    21.0       False       False       False
# 3                    29.0       False        True       False
# 4                    28.0       False       False       False

# %%
df_orders_new['days_since_prior_order'] = df_orders_new['days_since_prior_order'].fillna(0)

# %%
df_orders_new.head()
# Out:
#    order_id  user_id  order_n  order_dow  order_hour_of_day  \
# 0   2539329        1        1          2                  8
# 1   2398795        1        2          3                  7
# 2    473747        1        3          3                 12
# 3   2254736        1        4          4                  7
# 4    431534        1        5          4                 15
#
#    days_since_prior_order  is_weekend  is_morning  is_premium
# 0                     0.0       False        True       False
# 1                    15.0       False        True       False
# 2                    21.0       False       False       False
# 3                    29.0       False        True       False
# 4                    28.0       False       False       False

# %%
df_orders_new.to_csv('../data/processed/order.csv', index = False)

# %%
df_products = pd.read_csv('../data/raw/products.csv')
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_products.shape
# Out:
# (49693, 5)

# %%
df_products.drop(columns=['aisle_id'], inplace= True)

# %%
df_products.head()
# Out:
#    product_id                                       product_name  \
# 0           1                         Chocolate Sandwich Cookies
# 1           2                                   All-Seasons Salt
# 2           3               Robust Golden Unsweetened Oolong Tea
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           5                          Green Chile Anytime Sauce
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_departments = pd.read_csv('../data/raw/departments.csv')
df_departments.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_departments.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t = df_departments.T
df_dep_t.head()
# Out:
#                         0
# department_id  department
# 1                  frozen
# 2                   other
# 3                  bakery
# 4                 produce

# %%
df_departments.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  1 non-null      str
#  1   1              1 non-null      str
#  2   2              1 non-null      str
#  3   3              1 non-null      str
#  4   4              1 non-null      str
#  5   5              1 non-null      str
#  6   6              1 non-null      str
#  7   7              1 non-null      str
#  8   8              1 non-null      str
#  9   9              1 non-null      str
#  10  10             1 non-null      str
#  11  11             1 non-null      str
#  12  12             1 non-null      str
#  13  13             1 non-null      str
#  14  14             1 non-null      str
#  15  15             1 non-null      str
#  16  16             1 non-null      str
#  17  17             1 non-null      str
#  18  18             1 non-null      str
#  19  19             1 non-null      str
#  20  20             1 non-null      str
#  21  21             1 non-null      str
# dtypes: str(22)
# memory usage: 308.0 bytes

# %%
df_products.reset_index()
# Out:
#        index  product_id                                       product_name  \
# 0          0           1                         Chocolate Sandwich Cookies
# 1          1           2                                   All-Seasons Salt
# 2          2           3               Robust Golden Unsweetened Oolong Tea
# 3          3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4          4           5                          Green Chile Anytime Sauce
# ...      ...         ...                                                ...
# 49688  49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689  49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690  49690       49686                                   Artisan Baguette
# 49691  49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692  49692       49688                             Fresh Foaming Cleanser
#
#        department_id  prices
# 0                 19     5.8
# 1                 13     9.3
# 2                  7     4.5
# 3                  1    10.5
# 4                 13     4.3
# ...              ...     ...
# 49688              5     5.3
# 49689              1     3.1
# 49690              3     7.8
# 49691              8     4.7
# 49692             11    13.5
#
# [49693 rows x 5 columns]

# %%
df_dep_t.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21416\861038688.py in ?()
# ----> 1 df_dep_t.reset_index(inplace=True)
#
# c:\Users\elmir\miniconda3\envs\myenv\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    7320                     level_values = algorithms.take(
#    7321                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    7322                     )
#    7323
# -> 7324                 new_obj.insert(
#    7325                     0,
#    7326                     name,
#    7327                     level_values,
#
# c:\Users\elmir\miniconda3\envs\myenv\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5617                 "'self.flags.allows_duplicate_labels' is False."
#    5618             )
#    5619         if not allow_duplicates and column in self.columns:
#    5620             # Should this be a different kind of error??
# -> 5621             raise ValueError(f"cannot insert {column}, already exists")
#    5622         if not is_integer(loc):
#    5623             raise TypeError("loc must be int")
#    5624         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert level_0, already exists

# %%
new_header = df_dep_t.iloc[0]

# %%
df_dep_t_new = df_dep_t[1:]

# %%
col_names = df_departments.iloc[0]
col_names
# Out:
# department_id         department
# 1                         frozen
# 2                          other
# 3                         bakery
# 4                        produce
# 5                        alcohol
# 6                  international
# 7                      beverages
# 8                           pets
# 9                dry goods pasta
# 10                          bulk
# 11                 personal care
# 12                  meat seafood
# 13                        pantry
# 14                     breakfast
# 15                  canned goods
# 16                    dairy eggs
# 17                     household
# 18                        babies
# 19                        snacks
# 20                          deli
# 21                       missing
# Name: 0, dtype: str

# %%
#Setting the new header:
df_dep_t_new.columns = new_header

df_dep_t_new.head()
# Out:
# 0 department_id department
# 1             1     frozen
# 2             2      other
# 3             3     bakery
# 4             4    produce
# 5             5    alcohol

# %%
df_dep_t_new.to_csv("../data/processed/departments_t.csv", index=False)
