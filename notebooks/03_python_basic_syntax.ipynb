# %% [markdown]
# ## Arithmetic Operations

# %%
r = 1500
t = 0.2

total = r * (1 + t)
total
# Out:
# 1800.0

# %% [markdown]
# ## List

# %%
l = [10, 20, 30, 40]

# %%
l = [10, "test233", "mest", 50]

# %%
l
# Out:
# [10, 'test233', 'mest', 50]

# %%
len(l[1])
# Out:
# 7

# %%
len(l)
# Out:
# 4

# %%
l[0] = 11
l
# Out:
# [11, 'test233', 'mest', 50]

# %% [markdown]
# ## Tuple

# %%
t = (10, 12, 13)

# %% [markdown]
# ## Set

# %%
my_list = [1, 2, 3, 4, 5, 5, 5]

# %%
my_set = set(my_list)
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
a = {1, 1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}

# %%
a.intersection(b)
# Out:
# {4, 5}

# %% [markdown]
# ## Dictionary

# %%
# key value pairs
customers = {'Alice': 25,
             'Bob': 30,
             'Charlie': 35}

# %%
customers['Alice']
# Out:
# 25

# %%
customer1 = {'name': 'Alice', 'age': 25, 'city': 'NY', 'segment': 'Premium'}
customer1
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'NY', 'segment': 'Premium'}

# %%
#Bob
customer2 = {'name': 'Bob', 'age': 30, 'city': 'CA', 'segment': 'Standart'}
customer2
# Out:
# {'name': 'Bob', 'age': 30, 'city': 'CA', 'segment': 'Standart'}

# %%
#Bob
customer3 = {'name': 'Charlie', 'age': 325, 'city': 'Chicago', 'segment': 'Premium'}
customer3
# Out:
# {'name': 'Charlie', 'age': 325, 'city': 'Chicago', 'segment': 'Premium'}

# %%
list_of_customers = [customer1, customer2, customer3]

# %%
list_of_customers
# Out:
# [{'name': 'Alice', 'age': 25, 'city': 'NY', 'segment': 'Premium'},
#  {'name': 'Bob', 'age': 30, 'city': 'CA', 'segment': 'Standart'},
#  {'name': 'Charlie', 'age': 325, 'city': 'Chicago', 'segment': 'Premium'}]

# %%
list_of_customers[0]['name']
# Out:
# 'Alice'

# %%
list(list_of_customers[0].keys())
# Out:
# ['name', 'age', 'city', 'segment']

# %%
l = [10, 20, 30, 40]
d = {'key', 'value'}

# %%
import pandas as pd

# %%
data = {'name' : ['Alice', 'Bob', 'Charlie', 'David', 'Armen'],
        'age': [30, 25, 28, 40, 18],
        'city': ['New York', 'Los Angeles', 'Chicago', 'Boston', 'San Francisco']}

# %%
data['name']
data['age']
# Out:
# [30, 25, 28, 40, 18]

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#       name  age           city
# 0    Alice   30       New York
# 1      Bob   25    Los Angeles
# 2  Charlie   28        Chicago
# 3    David   40         Boston
# 4    Armen   18  San Francisco

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      str
#  1   age     5 non-null      int64
#  2   city    5 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 252.0 bytes

# %%
df.shape

f"{df.shape[0]} rows {df.shape[1]} columns"
# Out:
# '5 rows 3 columns'

# %%
list(df.columns)
# Out:
# ['name', 'age', 'city']

# %%
df.head(2)
# Out:
#     name  age         city
# 0  Alice   30     New York
# 1    Bob   25  Los Angeles

# %%
df['name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4      Armen
# Name: name, dtype: str

# %%
df[['name', 'age']]
# Out:
#       name  age
# 0    Alice   30
# 1      Bob   25
# 2  Charlie   28
# 3    David   40
# 4    Armen   18

# %%
df['State'] = 'Unknown'

# %%
df.head()
# Out:
#       name  age           city    State
# 0    Alice   30       New York  Unknown
# 1      Bob   25    Los Angeles  Unknown
# 2  Charlie   28        Chicago  Unknown
# 3    David   40         Boston  Unknown
# 4    Armen   18  San Francisco  Unknown

# %%
df['age'] = [int(i*0.9) for i in df['age']]
df.head()
# Out:
#       name  age           city
# 0    Alice   27       New York
# 1      Bob   22    Los Angeles
# 2  Charlie   25        Chicago
# 3    David   36         Boston
# 4    Armen   16  San Francisco

# %%
df.drop('State', axis=1)
# Out:
#       name  age           city
# 0    Alice   27       New York
# 1      Bob   22    Los Angeles
# 2  Charlie   25        Chicago
# 3    David   36         Boston
# 4    Armen   16  San Francisco

# %%
df[df['age'] > 30]
# Out:
#     name  age    city    State
# 3  David   36  Boston  Unknown

# %%
r = 100
t = 0.2

total = r * (1 + t)
total
# Out:
# 120.0

# %%
100 > 50
100 == 50
100 != 50
# Out:
# True

# %%
print((100 > 50) and (20 < 30))
# Out:
# True

# %%
sales = [100, 200,150, 200]
sales
# Out:
# [100, 200, 150, 200]

# %%
sales = [0]
sales = [-1]

# %%
a = 6
b = 5

# %%
a = a + b

# %%
sales = [100, 200, 150, 200]
sales
# Out:
# [100, 200, 150, 200]

# %%
sales[0]
# Out:
# 100

# %%
sales[-1]
# Out:
# 400

# %%
sales.append(300)
sales[1] = 250
sales
# Out:
# [100, 250, 150, 200, 300]

# %%
sales.remove(150)
sales
# Out:
# [100, 250, 200, 300]

# %%
len(sales)
# Out:
# 4

# %%
total = 0
for value in sales:
    total += value

total
# Out:
# 850

# %%
coordinates = (40.18, 44.51)
coordinates
# Out:
# (40.18, 44.51)

# %%
customer_ids = {1, 2, 3, 3, 4}
customer_ids
# Out:
# {1, 2, 3, 4}

# %%
segment_a = {1, 2, 3}
segment_b = {3, 4, 5}

segment_a.intersection(segment_b)
# Out:
# {3}

# %%
customer = {
    'name': "Anna",
    "revenue": 150,
    "city": "Yerevan"
}
customer
# Out:
# {'name': 'Anna', 'revenue': 150, 'city': 'Yerevan'}

# %%
customer["revenue"]
# Out:
# 150

# %%
customer["segment"] = "Premium"
customer["revenue"] = 200
customer
# Out:
# {'name': 'Anna', 'revenue': 200, 'city': 'Yerevan', 'segment': 'Premium'}

# %%
del customer["city"]

customer
# Out:
# {'name': 'Anna', 'revenue': 200, 'segment': 'Premium'}

# %%
customers = [
    {"name": "Anna", "revenue": 150},
    {"name": "David", "revenue": 220},
    {"name": "Mariam", "revenue": 90},
]
customers
# Out:
# [{'name': 'Anna', 'revenue': 150},
#  {'name': 'David', 'revenue': 220},
#  {'name': 'Mariam', 'revenue': 90}]

# %%
import pandas as pd

data = {
    "name": ["Anna", "David", "Mariam"],
    "revenue": [150, 220, 90],
    "city": ["Yerevan", "Tbilisi", "Warsaw"]
}

df = pd.DataFrame(data)
df
# Out:
#      name  revenue     city
# 0    Anna      150  Yerevan
# 1   David      220  Tbilisi
# 2  Mariam       90   Warsaw

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     3 non-null      str
#  1   revenue  3 non-null      int64
#  2   city     3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['name', 'revenue', 'city'], dtype='str')

# %%
df["revenue"]
# Out:
# 0    150
# 1    220
# 2     90
# Name: revenue, dtype: int64

# %%
df[["name", "revenue"]]
# Out:
#      name  revenue
# 0    Anna      150
# 1   David      220
# 2  Mariam       90

# %%
t = 0.2
df["revenue_after_tax"] = df["revenue"] * (1 - t)
df
# Out:
#      name  revenue     city  revenue_after_tax
# 0    Anna      150  Yerevan              120.0
# 1   David      220  Tbilisi              176.0
# 2  Mariam       90   Warsaw               72.0

# %%
df.drop("city", axis=1)
# Out:
#      name  revenue  revenue_after_tax
# 0    Anna      150              120.0
# 1   David      220              176.0
# 2  Mariam       90               72.0

# %%
df.drop("city", axis=1)
df
# Out:
#      name  revenue     city  revenue_after_tax
# 0    Anna      150  Yerevan              120.0
# 1   David      220  Tbilisi              176.0
# 2  Mariam       90   Warsaw               72.0

# %%
df
# Out:
#      name  revenue     city  revenue_after_tax
# 0    Anna      150  Yerevan              120.0
# 1   David      220  Tbilisi              176.0
# 2  Mariam       90   Warsaw               72.0

# %%
df[df["revenue"] > 100]
# Out:
#     name  revenue     city  revenue_after_tax
# 0   Anna      150  Yerevan              120.0
# 1  David      220  Tbilisi              176.0

# %%
df.loc[df["revenue"] < 100, "segment"] = "Low"
df.loc[df["revenue"] >= 100, "segment"] = "High"
df
# Out:
#      name  revenue     city  revenue_after_tax segment
# 0    Anna      150  Yerevan              120.0    High
# 1   David      220  Tbilisi              176.0    High
# 2  Mariam       90   Warsaw               72.0     Low

# %%
revenue = 150

if revenue > 100:
    print("High revenue")
else:
    print("Low revenue")
# Out:
# High revenue

# %%
revenue = 150

if revenue > 100:
    print("High revenue")

print("Analysis complete")
# Out:
# High revenue
# Analysis complete

# %%
revenue = 180

if revenue > 200:
    print("Very high revenue")
elif revenue > 100:
    print("High revenue")
elif revenue > 50:
    print("Medium revenue")
else:
    print("Low revenue")
# Out:
# High revenue

# %%
revenue = 150
is_active = True

if revenue > 100 and is_active:
    print("Target customer")
# Out:
# Target customer

# %%
is_active = False
if not is_active:
    print("Customer is inactive")
# Out:
# Customer is inactive

# %%
revenue = 150
region = "EU"

if revenue > 100:
    if region == "EU":
        print("High EU revenue")
    else:
        print("High non-EU revenue")
# Out:
# High EU revenue

# %%
sales = [100, 200, 150]

for i in sales:
    print(i)
# Out:
# 100
# 200
# 150

# %%
sales = [100, 200, 150]
total = 0

for i in sales:
    total += i
total
# Out:
# 450

# %%
sales = [100, 200, 150, 50]

for i in sales:
    if i > 120:
        print("High sales:", i)
# Out:
# High sales: 200
# High sales: 150

# %%
customer = {
    "name": "Anna",
    "revenue": 150,
    "city": "Yerevan"
}

# for i in customer:
#     print(i, ":", customer[i])

for key, value in customer.items():
    print(key, value)
# Out:
# name Anna
# revenue 150
# city Yerevan

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(3):
    for j in range(2):
        print("i=", i, ", j=", j)
# Out:
# i= 0 , j= 0
# i= 0 , j= 1
# i= 1 , j= 0
# i= 1 , j= 1
# i= 2 , j= 0
# i= 2 , j= 1

# %%
sales = [100, 200, 150]
new_sales = []

for i in sales:
    new_sales.append(i * 1.2)

new_sales
# Out:
# [120.0, 240.0, 180.0]

# %%
sales = [100, 200, 150]

new_sales = [i * 1.2 for i in sales]
new_sales
# Out:
# [120.0, 240.0, 180.0]

# %%
sales = [100, 200, 150, 50]

high_sales = [i for i in sales if i > 120]
high_sales
# Out:
# [200, 150]

# %%
sales = [100, 200, 150, 50]

labels = ["high" if i > 120 else "Low" for i in sales]
labels
# Out:
# ['Low', 'high', 'high', 'Low']
